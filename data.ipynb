# %%
import pandas as pd

# %%
# %pip install xlrd
# Out:
# ...
#   Obtaining dependency information for xlrd from https://files.pythonhosted.org/packages/a6/0c/c2a72d51fe56e08a08acc85d13013558a2d793028ae7385448a6ccdfae64/xlrd-2.0.1-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/96.5 kB 262.6 kB/s eta 0:00:01
#    ------------------------- -------------- 61.4/96.5 kB 409.6 kB/s eta 0:00:01
#    ---------------------------------------- 96.5/96.5 kB 616.4 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel('./50.PEC/Dataset.xls', sheet_name='Listado de tickets INC-PET')

# %%
df.head(10)
# Out:
#        Fecha Creación Número de incidente  \
# 0 2020-01-15 10:08:26     INC002000000012
# 1 2020-01-15 10:21:01     INC002000000013
# 2 2020-01-15 11:38:42     INC002000000014
# 3 2020-01-15 12:10:48     INC002000000016
# 4 2020-01-15 12:13:53     INC002000000017
# 5 2020-01-15 12:14:22     INC002000000018
# 6 2020-01-15 12:16:33     INC002000000019
# 7 2020-01-15 12:19:43     INC002000000020
# 8 2020-01-15 12:24:11     INC002000000022
# 9 2020-01-15 12:30:59     INC002000000023
#
#                                          Descripción    Servicio  \
# 0                                             Prueba     CHRONOS
# 1                                            Hello!         DUNA
# 2  TRAFUL/SNS: Inclusión a lista de distribucción...      TRAFUL
# 3  Necesito cambiar un canal Publico a privado de...  OFFICE 365
# 4  Error Duplicidad de Registros cuando accedo a ...       BI_EN
# 5               esto es uan prueba por favor ignorar     CHRONOS
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58564 entries, 0 to 58563
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Fecha Creación           58564 non-null  datetime64[ns]
#  1   Número de incidente      58564 non-null  object
#  2   Descripción              58560 non-null  object
#  3   Servicio                 58529 non-null  object
#  4   Tipo de Servicio         58564 non-null  object
#  5   Prioridad                58564 non-null  object
#  6   Estado                   58564 non-null  object
#  7   Torre                    58479 non-null  object
#  8   Entorno                  47775 non-null  object
#  9   Estado cumplimiento SLA  54557 non-null  object
#  10  Duración días            58564 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(9)
# memory usage: 4.9+ MB
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# ...
